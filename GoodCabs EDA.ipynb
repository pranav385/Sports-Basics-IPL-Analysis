# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
monthly_target_trips = pd.read_csv('monthly_target_trips.csv')
monthly_target_new_passengers = pd.read_csv('monthly_target_new_passengers.csv')
fact_trips = pd.read_csv('fact_trips.csv')
fact_passenger_summary = pd.read_csv('fact_passenger_summary.csv')
dim_repeat_trip_distribution = pd.read_csv('dim_repeat_trip_distribution.csv')
dim_date = pd.read_csv('dim_date.csv')
dim_city = pd.read_csv('dim_city.csv')
city_target_passenger_rating = pd.read_csv('city_target_passenger_rating.csv')

# %%
fact_trips.head()
# Out:
#                 trip_id        date city_id passenger_type  \
# 0  TRPLUC240113d55de2fb  2024-01-13    UP01       repeated
# 1  TRPVAD240129a3b6dba8  2024-01-29    GJ02       repeated
# 2  TRPCOI240107a42430fb  2024-01-07    TN01       repeated
# 3  TRPKOC240325d7601389  2024-03-25    KL01       repeated
# 4  TRPVIS2406027be97166  2024-06-02    AP01            new
#
#    distance_travelled(km)  fare_amount  passenger_rating  driver_rating
# 0                      11          158                 5              5
# 1                       7           74                 5              5
# 2                      11          155                 8              8
# 3                      36          427                 9             10
# 4                      17          265                 8              8

# %% [markdown]
# ### 1. Top and Bottom Performing Cities
# ### . Identify the top 3 and bottom 3 cities by total trips over the entire analysis period.

# %%
df1 = fact_trips.groupby(['city_id'])['trip_id'].count().reset_index(name='Trip Count')
df1.sort_values(by=['Trip Count'], ascending = [False], inplace=True)
df1 = pd.merge(df1, dim_city, on=['city_id'], how='inner')
print('Top 3 Cities')
print(df1[['city_name', 'Trip Count']].head(3))
print('-'* 50)
print('Bottom 3 Cities')
print(df1[['city_name', 'Trip Count']].tail(3))
# Out:
# Top 3 Cities
#   city_name  Trip Count
# 0    Jaipur       76888
# 1   Lucknow       64299
# 2     Surat       54843
# --------------------------------------------------
# Bottom 3 Cities
#        city_name  Trip Count
# 7  Visakhapatnam       28366
# 8     Coimbatore       21104
# 9         Mysore       16238

# %% [markdown]
# ### 2. Average Fare per Trip by City
# ### Calculate the average fare per trip for each city and compare it with the city's average trip distance. Identify the cities with the highest and lowest average fare per trip to assess pricing efficiency across locations.

# %%
df2 = fact_trips.groupby(['city_id']).agg(
    Avg_Fare_Trip = ('fare_amount', 'mean'),
    Avg_Distance_Trip = ('distance_travelled(km)', 'mean')
).reset_index()
df2.sort_values(by=['Avg_Fare_Trip'], ascending=[False], inplace=True)
df2 = pd.merge(df2, dim_city, on=['city_id'], how='inner')
print(df2)
print('-'* 50)
print('Highest Average Fare Per Trip')
print(df2[['city_name', 'Avg_Fare_Trip', 'Avg_Distance_Trip']].head(1))
print('-'* 50)
print('Lowest Average Fare Per Trip')
df2[['city_name', 'Avg_Fare_Trip', 'Avg_Distance_Trip']].tail(1)
# Out:
#   city_id  Avg_Fare_Trip  Avg_Distance_Trip      city_name
# 0    RJ01     483.918128          30.023125         Jaipur
# 1    KL01     335.245079          24.065461          Kochi
# 2    CH01     283.686950          23.518714     Chandigarh
# 3    AP01     282.672284          22.553938  Visakhapatnam
# 4    KA01     249.707168          16.496921         Mysore
# 5    MP01     179.838609          16.502473         Indore
# 6    TN01     166.982183          14.979198     Coimbatore
# 7    UP01     147.180376          12.512963        Lucknow
# 8    GJ02     118.566165          11.517736       Vadodara
# 9    GJ01     117.272925          10.997247          Surat
# --------------------------------------------------
# Highest Average Fare Per Trip
#   city_name  Avg_Fare_Trip  Avg_Distance_Trip
# 0    Jaipur     483.918128          30.023125
# --------------------------------------------------
# Lowest Average Fare Per Trip
#   city_name  Avg_Fare_Trip  Avg_Distance_Trip
# 9     Surat     117.272925          10.997247

# %% [markdown]
# ### 3. Average Ratings by City and Passenger Type
# ### Calculate the average passenger and driver ratings for each city, segmented by passenger type (new vs. repeat). Identify cities with the highest and lowest average ratings.

# %%
df3 = fact_trips.groupby(['city_id','passenger_type']).agg(
    Avg_Passenger_Rating = ('passenger_rating', 'mean'),
    Avg_Driver_Rating = ('driver_rating', 'mean')
).reset_index()
df3 = pd.merge(df3, dim_city, on=['city_id'], how='inner')
df3 = df3[['city_name', 'passenger_type', 'Avg_Passenger_Rating', 'Avg_Driver_Rating']]
df3
# Out:
#         city_name passenger_type  Avg_Passenger_Rating  Avg_Driver_Rating
# 0   Visakhapatnam            new              8.976151           8.979995
# 1   Visakhapatnam       repeated              7.989628           8.992701
# 2      Chandigarh            new              8.489158           7.992120
# 3      Chandigarh       repeated              7.493798           7.472824
# 4           Surat            new              7.984173           6.994925
# 5           Surat       repeated              5.995511           6.479441
# 6        Vadodara            new              7.979263           7.004147
# 7        Vadodara       repeated              5.978629           6.481072
# 8          Mysore            new              8.982964           8.982878
# 9          Mysore       repeated              7.978495           8.965767
# 10          Kochi            new              8.987394           8.985350
# 11          Kochi       repeated              8.003665           8.989830
# 12         Indore            new              8.485837           7.970800
# 13         Indore       repeated              7.473961           7.477404
# 14         Jaipur            new              8.985018           8.988246
# 15         Jaipur       repeated              7.991042           8.984790
# 16     Coimbatore            new              8.485788           7.990604
# 17     Coimbatore       repeated              7.475457           7.480778
# 18        Lucknow            new              7.977429           6.990406
# 19        Lucknow       repeated              5.985741           6.491663

# %%
print('Highest Rated by Repated Passenger')
print(df3[df3['passenger_type']=='repeated'].sort_values(by=['Avg_Passenger_Rating'], ascending=False).head(1))
print('-'*50)
print('Lowest Rated by Repated Passenger')
print(df3[df3['passenger_type']=='repeated'].sort_values(by=['Avg_Passenger_Rating'], ascending=False).tail(1))
print('-'*50)
print('Highest Rated by New Passenger')
print(df3[df3['passenger_type']=='new'].sort_values(by=['Avg_Passenger_Rating'], ascending=False).head(1))
print('-'*50)
print('Lowest Rated by New Passenger')
print(df3[df3['passenger_type']=='new'].sort_values(by=['Avg_Passenger_Rating'], ascending=False).tail(1))
# Out:
# Highest Rated by Repated Passenger
#    city_name passenger_type  Avg_Passenger_Rating  Avg_Driver_Rating
# 11     Kochi       repeated              8.003665            8.98983
# --------------------------------------------------
# Lowest Rated by Repated Passenger
#   city_name passenger_type  Avg_Passenger_Rating  Avg_Driver_Rating
# 7  Vadodara       repeated              5.978629           6.481072
# --------------------------------------------------
# Highest Rated by New Passenger
#    city_name passenger_type  Avg_Passenger_Rating  Avg_Driver_Rating
# 10     Kochi            new              8.987394            8.98535
# --------------------------------------------------
# Lowest Rated by New Passenger
#    city_name passenger_type  Avg_Passenger_Rating  Avg_Driver_Rating
# 18   Lucknow            new              7.977429           6.990406

# %% [markdown]
# ### 4. Peak and Low Demand Months by City
# ### For each city, identify the month with the highest total trips (peak demand) and the month with the lowest total trips (low demand). This analysis will help Goodcabs understand seasonal patterns and adjust resources accordingly.

# %%
fact_trips['date'] = pd.to_datetime(fact_trips['date'])
df4 = fact_trips.copy()
df4['month_name'] = fact_trips['date'].dt.month_name()
df4.head()
# Out:
#                 trip_id       date city_id passenger_type  \
# 0  TRPLUC240113d55de2fb 2024-01-13    UP01       repeated
# 1  TRPVAD240129a3b6dba8 2024-01-29    GJ02       repeated
# 2  TRPCOI240107a42430fb 2024-01-07    TN01       repeated
# 3  TRPKOC240325d7601389 2024-03-25    KL01       repeated
# 4  TRPVIS2406027be97166 2024-06-02    AP01            new
#
#    distance_travelled(km)  fare_amount  passenger_rating  driver_rating  \
# 0                      11          158                 5              5
# 1                       7           74                 5              5
# 2                      11          155                 8              8
# 3                      36          427                 9             10
# 4                      17          265                 8              8
#
#   month_name
# 0    January
# 1    January
# 2    January
# 3      March
# 4       June

# %%
df4 = df4.groupby(['city_id', 'month_name'])['trip_id'].count().reset_index(name='Trip Count')
df4['rank1'] = df4.groupby(['city_id'])['Trip Count'].rank(method = 'dense', ascending = False)
df4['rank2'] = df4.groupby(['city_id'])['Trip Count'].rank(method = 'dense', ascending = True)
df4 = df4[(df4['rank1']==1) | (df4['rank2']==1)]
df4 = pd.merge(df4, dim_city, on=['city_id'], how='inner')
df4[['city_name', 'month_name', 'Trip Count']]
# Out:
#         city_name month_name  Trip Count
# 0   Visakhapatnam      April        4938
# 1   Visakhapatnam    January        4468
# 2      Chandigarh      April        5566
# 3      Chandigarh   February        7387
# 4           Surat      April        9831
# 5           Surat    January        8358
# 6        Vadodara      April        5941
# 7        Vadodara       June        4685
# 8          Mysore    January        2485
# 9          Mysore        May        3007
# 10          Kochi       June        6399
# 11          Kochi        May       10014
# 12         Indore       June        6288
# 13         Indore        May        7787
# 14         Jaipur   February       15872
# 15         Jaipur       June        9842
# 16     Coimbatore       June        3158
# 17     Coimbatore      March        3680
# 18        Lucknow   February       12060
# 19        Lucknow        May        9705

# %% [markdown]
# ### 5. Weekend vs. Weekday Trip Demand by City
# ### Compare the total trips taken on weekdays versus weekends for each city over the six-month period. Identify cities with a strong preference for either weekend or weekday trips to understand demand variations.

# %%
dim_date['date'] = pd.to_datetime(dim_date['date'])

# %%
df5 = pd.merge(fact_trips, dim_date, on=['date'], how='inner')
df5.head()
# Out:
#                 trip_id       date city_id passenger_type  \
# 0  TRPLUC240113d55de2fb 2024-01-13    UP01       repeated
# 1  TRPVAD240129a3b6dba8 2024-01-29    GJ02       repeated
# 2  TRPCOI240107a42430fb 2024-01-07    TN01       repeated
# 3  TRPKOC240325d7601389 2024-03-25    KL01       repeated
# 4  TRPVIS2406027be97166 2024-06-02    AP01            new
#
#    distance_travelled(km)  fare_amount  passenger_rating  driver_rating  \
# 0                      11          158                 5              5
# 1                       7           74                 5              5
# 2                      11          155                 8              8
# 3                      36          427                 9             10
# 4                      17          265                 8              8
#
#   start_of_month month_name day_type
# 0     2024-01-01    January  Weekend
# 1     2024-01-01    January  Weekday
# 2     2024-01-01    January  Weekend
# 3     2024-03-01      March  Weekday
# 4     2024-06-01       June  Weekend

# %%
df5 = df5.groupby(['city_id', 'day_type'])['trip_id'].count().reset_index(name='Trip_Count')
df5
# Out:
#    city_id day_type  Trip_Count
# 0     AP01  Weekday       15100
# 1     AP01  Weekend       13266
# 2     CH01  Weekday       19914
# 3     CH01  Weekend       19067
# 4     GJ01  Weekday       37793
# 5     GJ01  Weekend       17050
# 6     GJ02  Weekday       20310
# 7     GJ02  Weekend       11716
# 8     KA01  Weekday        6424
# 9     KA01  Weekend        9814
# 10    KL01  Weekday       22915
# 11    KL01  Weekend       27787
# 12    MP01  Weekday       21198
# 13    MP01  Weekend       21258
# 14    RJ01  Weekday       32491
# 15    RJ01  Weekend       44397
# 16    TN01  Weekday       12576
# 17    TN01  Weekend        8528
# 18    UP01  Weekday       49617
# 19    UP01  Weekend       14682

# %%
df5 = df5.pivot(index="city_id", columns="day_type", values="Trip_Count").reset_index()

df5.columns.name = None 
df5 = df5.rename(columns={"Weekday": "Weekday_Trips", "Weekend": "Weekend_Trips"})

df5
# Out:
#   city_id  Weekday_Trips  Weekend_Trips
# 0    AP01          15100          13266
# 1    CH01          19914          19067
# 2    GJ01          37793          17050
# 3    GJ02          20310          11716
# 4    KA01           6424           9814
# 5    KL01          22915          27787
# 6    MP01          21198          21258
# 7    RJ01          32491          44397
# 8    TN01          12576           8528
# 9    UP01          49617          14682

# %%
df5['Choice'] = np.where(df5['Weekday_Trips']>df5['Weekend_Trips'], 'People prefer traviling on Weekdays', 'People prefer traviling on Weekends')
df5 = pd.merge(df5, dim_city, on=['city_id'], how='inner')
df5[['city_name', 'Weekday_Trips', 'Weekend_Trips', 'Choice']]
# Out:
#        city_name  Weekday_Trips  Weekend_Trips  \
# 0  Visakhapatnam          15100          13266
# 1     Chandigarh          19914          19067
# 2          Surat          37793          17050
# 3       Vadodara          20310          11716
# 4         Mysore           6424           9814
# 5          Kochi          22915          27787
# 6         Indore          21198          21258
# 7         Jaipur          32491          44397
# 8     Coimbatore          12576           8528
# 9        Lucknow          49617          14682
#
#                                 Choice
# 0  People prefer traviling on Weekdays
# 1  People prefer traviling on Weekdays
# 2  People prefer traviling on Weekdays
# 3  People prefer traviling on Weekdays
# 4  People prefer traviling on Weekends
# 5  People prefer traviling on Weekends
# 6  People prefer traviling on Weekends
# 7  People prefer traviling on Weekends
# 8  People prefer traviling on Weekdays
# 9  People prefer traviling on Weekdays

# %% [markdown]
# ### 6. Repeat Passenger Frequency and City Contribution Analysis
# ### Analyse the frequency of trips taken by repeat passengers in each city (e.g., % of repeat passengers taking 2 trips, 3 trips, etc.). Identify which cities contribute most to higher trip frequencies among repeat passengers, and examine if there are distinguishable patterns between tourism-focused and business-focused cities.

# %%
df6 = dim_repeat_trip_distribution.groupby(['city_id','trip_count'])['repeat_passenger_count'].sum().reset_index()
df6.head()
# Out:
#   city_id trip_count  repeat_passenger_count
# 0    AP01   10-Trips                      47
# 1    AP01    2-Trips                    2618
# 2    AP01    3-Trips                    1275
# 3    AP01    4-Trips                     510
# 4    AP01    5-Trips                     278

# %%
df6 = df6.pivot(index="city_id", columns="trip_count", values="repeat_passenger_count").reset_index()

# Rename columns for clarity (optional)
df6.columns.name = None  # Remove the column grouping name

df6
# Out:
#   city_id  10-Trips  2-Trips  3-Trips  4-Trips  5-Trips  6-Trips  7-Trips  \
# 0    AP01        47     2618     1275      510      278      163      101
# 1    CH01        91     1638      976      798      619      376      278
# 2    GJ01       117      843     1232     1430     1706     1594     1027
# 3    GJ02        70      429      616      718      785      829      559
# 4    KA01         7      720      361      188       86       60       26
# 5    KL01        62     3635     1857      901      494      298      161
# 6    MP01       109     2478     1637      967      746      494      378
# 7    RJ01        94     4855     2007     1173      609      400      244
# 8    TN01        31      286      378      397      526      450      267
# 9    UP01       106      927     1417     1555     1768     1937     1087
#
#    8-Trips  9-Trips
# 0       71       45
# 1      176      118
# 2      539      150
# 3      251       89
# 4       21        8
# 5      126       92
# 6      235      172
# 7      184      116
# 8      157       59
# 9      617      183

# %%
df6_1 = dim_repeat_trip_distribution.groupby(['city_id'])['repeat_passenger_count'].sum().reset_index()
df6_1
# Out:
#   city_id  repeat_passenger_count
# 0    AP01                    5108
# 1    CH01                    5070
# 2    GJ01                    8638
# 3    GJ02                    4346
# 4    KA01                    1477
# 5    KL01                    7626
# 6    MP01                    7216
# 7    RJ01                    9682
# 8    TN01                    2551
# 9    UP01                    9597

# %%
df6 = pd.merge(df6, df6_1, on=['city_id'], how='inner')
df6
# Out:
#   city_id  10-Trips  2-Trips  3-Trips  4-Trips  5-Trips  6-Trips  7-Trips  \
# 0    AP01        47     2618     1275      510      278      163      101
# 1    CH01        91     1638      976      798      619      376      278
# 2    GJ01       117      843     1232     1430     1706     1594     1027
# 3    GJ02        70      429      616      718      785      829      559
# 4    KA01         7      720      361      188       86       60       26
# 5    KL01        62     3635     1857      901      494      298      161
# 6    MP01       109     2478     1637      967      746      494      378
# 7    RJ01        94     4855     2007     1173      609      400      244
# 8    TN01        31      286      378      397      526      450      267
# 9    UP01       106      927     1417     1555     1768     1937     1087
#
#    8-Trips  9-Trips  repeat_passenger_count
# 0       71       45                    5108
# 1      176      118                    5070
# 2      539      150                    8638
# 3      251       89                    4346
# 4       21        8                    1477
# 5      126       92                    7626
# 6      235      172                    7216
# 7      184      116                    9682
# 8      157       59                    2551
# 9      617      183                    9597

# %%
trip_columns = [col for col in df6.columns if col not in ["city_id", "repeat_passenger_count"]]
for col in trip_columns:
    df6[col] = round((df6[col] / df6["repeat_passenger_count"]) * 100,2)

df6 = df6[["city_id","2-Trips", "3-Trips", "4-Trips", "5-Trips", "6-Trips", "7-Trips", "8-Trips", "9-Trips", "10-Trips"]]
df6 = pd.merge(df6, dim_city, on=['city_id'], how='inner')
df6[["city_name","2-Trips", "3-Trips", "4-Trips", "5-Trips", "6-Trips", "7-Trips", "8-Trips", "9-Trips", "10-Trips"]]
# Out:
#        city_name  2-Trips  3-Trips  4-Trips  5-Trips  6-Trips  7-Trips  \
# 0  Visakhapatnam    51.25    24.96     9.98     5.44     3.19     1.98
# 1     Chandigarh    32.31    19.25    15.74    12.21     7.42     5.48
# 2          Surat     9.76    14.26    16.55    19.75    18.45    11.89
# 3       Vadodara     9.87    14.17    16.52    18.06    19.08    12.86
# 4         Mysore    48.75    24.44    12.73     5.82     4.06     1.76
# 5          Kochi    47.67    24.35    11.81     6.48     3.91     2.11
# 6         Indore    34.34    22.69    13.40    10.34     6.85     5.24
# 7         Jaipur    50.14    20.73    12.12     6.29     4.13     2.52
# 8     Coimbatore    11.21    14.82    15.56    20.62    17.64    10.47
# 9        Lucknow     9.66    14.77    16.20    18.42    20.18    11.33
#
#    8-Trips  9-Trips  10-Trips
# 0     1.39     0.88      0.92
# 1     3.47     2.33      1.79
# 2     6.24     1.74      1.35
# 3     5.78     2.05      1.61
# 4     1.42     0.54      0.47
# 5     1.65     1.21      0.81
# 6     3.26     2.38      1.51
# 7     1.90     1.20      0.97
# 8     6.15     2.31      1.22
# 9     6.43     1.91      1.10

# %% [markdown]
# ### 7. Monthly Target Achievement Analysis for Key Metrics
# ### For each city, evaluate monthly performance against targets for total trips, new passengers, and average passenger ratings from targets_db. Determine if each metric met, exceeded, or missed the target, and calculate the percentage difference. Identify any consistent patterns in target achievement, particularly across tourism versus business-focused cities.

# %%
df7 = fact_trips.copy()
df7['month_name'] = df7['date'].dt.month_name()
df7 = df7.groupby(['city_id', 'month_name']).agg(
    Total_Trips = ('trip_id', 'count'),
    Avg_Passenger_Rating = ('passenger_rating', 'mean')
).reset_index()
df7.head()
# Out:
#   city_id month_name  Total_Trips  Avg_Passenger_Rating
# 0    AP01      April         4938              8.370595
# 1    AP01   February         4793              8.465262
# 2    AP01    January         4468              8.553939
# 3    AP01       June         4478              8.402188
# 4    AP01      March         4877              8.426287

# %%
fact_passenger_summary['month'] = pd.to_datetime(fact_passenger_summary['month'])

# %%
df7_1 = fact_passenger_summary.copy()
df7_1['month_name'] = df7_1['month'].dt.month_name()
df7_1.head()
# Out:
#        month city_id  new_passengers  repeat_passengers  total_passengers  \
# 0 2024-01-01    AP01            2513                650              3163
# 1 2024-01-01    CH01            3920                720              4640
# 2 2024-01-01    GJ01            2432               1184              3616
# 3 2024-01-01    GJ02            2089                544              2633
# 4 2024-01-01    KA01            1957                172              2129
#
#   month_name
# 0    January
# 1    January
# 2    January
# 3    January
# 4    January

# %%
df7_1 = df7_1.groupby(['city_id', 'month_name'])['new_passengers'].sum().reset_index(name='Total_New_Passengers')
df7_1.head()
# Out:
#   city_id month_name  Total_New_Passengers
# 0    AP01      April                  1845
# 1    AP01   February                  2380
# 2    AP01    January                  2513
# 3    AP01       June                  1900
# 4    AP01      March                  2170

# %%
df7 = pd.merge(df7, df7_1, on=['city_id', 'month_name'], how='inner')
df7.head()
# Out:
#   city_id month_name  Total_Trips  Avg_Passenger_Rating  Total_New_Passengers
# 0    AP01      April         4938              8.370595                  1845
# 1    AP01   February         4793              8.465262                  2380
# 2    AP01    January         4468              8.553939                  2513
# 3    AP01       June         4478              8.402188                  1900
# 4    AP01      March         4877              8.426287                  2170

# %%
monthly_target_trips['month'] = pd.to_datetime(monthly_target_trips['month'])
monthly_target_trips['month_name'] = monthly_target_trips['month'].dt.month_name()
monthly_target_trips.head()
# Out:
#        month city_id  total_target_trips month_name
# 0 2024-03-01    MP01                7000      March
# 1 2024-05-01    KA01                2500        May
# 2 2024-04-01    UP01               11000      April
# 3 2024-02-01    GJ02                6000   February
# 4 2024-05-01    KL01                9000        May

# %%
df7 = pd.merge(df7, monthly_target_trips, on=['city_id', 'month_name'], how='inner')
df7 = df7[['city_id','month_name', 'Total_Trips', 'Avg_Passenger_Rating', 'Total_New_Passengers', 'total_target_trips']]
df7.head()
# Out:
#   city_id month_name  Total_Trips  Avg_Passenger_Rating  Total_New_Passengers  \
# 0    AP01      April         4938              8.370595                  1845
# 1    AP01   February         4793              8.465262                  2380
# 2    AP01    January         4468              8.553939                  2513
# 3    AP01       June         4478              8.402188                  1900
# 4    AP01      March         4877              8.426287                  2170
#
#    total_target_trips
# 0                5000
# 1                4500
# 2                4500
# 3                5000
# 4                4500

# %%
monthly_target_new_passengers['month'] = pd.to_datetime(monthly_target_new_passengers['month'])
monthly_target_new_passengers['month_name'] = monthly_target_new_passengers['month'].dt.month_name()
monthly_target_new_passengers.head()
# Out:
#        month city_id  target_new_passengers month_name
# 0 2024-05-01    GJ01                   1500        May
# 1 2024-05-01    GJ02                   1500        May
# 2 2024-03-01    GJ01                   2000      March
# 3 2024-05-01    UP01                   2000        May
# 4 2024-05-01    MP01                   2000        May

# %%
df7 = pd.merge(df7, monthly_target_new_passengers, on=['city_id', 'month_name'], how='inner')
df7 = df7.drop(['month'], axis=1)
df7.head()
# Out:
#   city_id month_name  Total_Trips  Avg_Passenger_Rating  Total_New_Passengers  \
# 0    AP01      April         4938              8.370595                  1845
# 1    AP01   February         4793              8.465262                  2380
# 2    AP01    January         4468              8.553939                  2513
# 3    AP01       June         4478              8.402188                  1900
# 4    AP01      March         4877              8.426287                  2170
#
#    total_target_trips  target_new_passengers
# 0                5000                   2000
# 1                4500                   2500
# 2                4500                   2500
# 3                5000                   2000
# 4                4500                   2500

# %%
df7 = pd.merge(df7, city_target_passenger_rating, on=['city_id'], how='inner')
df7.head()
# Out:
#   city_id month_name  Total_Trips  Avg_Passenger_Rating  Total_New_Passengers  \
# 0    AP01      April         4938              8.370595                  1845
# 1    AP01   February         4793              8.465262                  2380
# 2    AP01    January         4468              8.553939                  2513
# 3    AP01       June         4478              8.402188                  1900
# 4    AP01      March         4877              8.426287                  2170
#
#    total_target_trips  target_new_passengers  target_avg_passenger_rating
# 0                5000                   2000                          8.5
# 1                4500                   2500                          8.5
# 2                4500                   2500                          8.5
# 3                5000                   2000                          8.5
# 4                4500                   2500                          8.5

# %%
df7['Trips_Target'] = np.where(
    df7['Total_Trips'] > df7['total_target_trips'], 
    'Exceeds Target by ' + round((df7['Total_Trips'] - df7['total_target_trips']) * 100 / df7['total_target_trips'], 2).astype(str) + '%',
    np.where(
        df7['Total_Trips'] < df7['total_target_trips'], 
        'Lags Target by ' + round((df7['Total_Trips'] - df7['total_target_trips']) * 100 / df7['total_target_trips'], 2).astype(str) + '%',
        'Same'
    )
)

df7['New_Passenger_Target'] = np.where(
    df7['Total_New_Passengers'] > df7['target_new_passengers'], 
    'Exceeds Target by ' + round((df7['Total_New_Passengers'] - df7['target_new_passengers']) * 100 / df7['target_new_passengers'], 2).astype(str) + '%',
    np.where(
        df7['Total_New_Passengers'] < df7['target_new_passengers'], 
        'Lags Target by ' + round((df7['Total_New_Passengers'] - df7['target_new_passengers']) * 100 / df7['target_new_passengers'], 2).astype(str) + '%',
        'Same'
    )
)

df7['Avg_Rating_Target'] = np.where(
    df7['Avg_Passenger_Rating'] > df7['target_avg_passenger_rating'], 
    'Exceeds Target by ' + round((df7['Avg_Passenger_Rating'] - df7['target_avg_passenger_rating']) * 100 / df7['target_avg_passenger_rating'], 2).astype(str) + '%',
    np.where(
        df7['Avg_Passenger_Rating'] < df7['target_avg_passenger_rating'], 
        'Lags Target by ' + round((df7['Avg_Passenger_Rating'] - df7['target_avg_passenger_rating']) * 100 / df7['target_avg_passenger_rating'], 2).astype(str) + '%',
        'Same'
    )
)

df7 = pd.merge(df7, dim_city, on=['city_id'], how='inner')
df7.head()
# Out:
#   city_id month_name  Total_Trips  Avg_Passenger_Rating  Total_New_Passengers  \
# 0    AP01      April         4938              8.370595                  1845
# 1    AP01   February         4793              8.465262                  2380
# 2    AP01    January         4468              8.553939                  2513
# 3    AP01       June         4478              8.402188                  1900
# 4    AP01      March         4877              8.426287                  2170
#
#    total_target_trips  target_new_passengers  target_avg_passenger_rating  \
# 0                5000                   2000                          8.5
# 1                4500                   2500                          8.5
# 2                4500                   2500                          8.5
# 3                5000                   2000                          8.5
# 4                4500                   2500                          8.5
#
#               Trips_Target     New_Passenger_Target        Avg_Rating_Target  \
# 0    Lags Target by -1.24%    Lags Target by -7.75%    Lags Target by -1.52%
# 1  Exceeds Target by 6.51%     Lags Target by -4.8%    Lags Target by -0.41%
# 2    Lags Target by -0.71%  Exceeds Target by 0.52%  Exceeds Target by 0.63%
# 3   Lags Target by -10.44%     Lags Target by -5.0%    Lags Target by -1.15%
# 4  Exceeds Target by 8.38%    Lags Target by -13.2%    Lags Target by -0.87%
#
#        city_name
# 0  Visakhapatnam
# 1  Visakhapatnam
# 2  Visakhapatnam
# 3  Visakhapatnam
# 4  Visakhapatnam

# %%
df7 = df7[['city_name', 'month_name', 'Total_Trips', 'total_target_trips', 'Trips_Target', 'Total_New_Passengers', 'target_new_passengers',
    'New_Passenger_Target', 'Avg_Passenger_Rating', 'target_avg_passenger_rating', 'Avg_Rating_Target']]
df7
# Out:
#         city_name month_name  Total_Trips  total_target_trips  \
# 0   Visakhapatnam      April         4938                5000
# 1   Visakhapatnam   February         4793                4500
# 2   Visakhapatnam    January         4468                4500
# 3   Visakhapatnam       June         4478                5000
# 4   Visakhapatnam      March         4877                4500
# 5   Visakhapatnam        May         4812                5000
# 6      Chandigarh      April         5566                6000
# 7      Chandigarh   February         7387                7000
# 8      Chandigarh    January         6810                7000
# 9      Chandigarh       June         6029                6000
# 10     Chandigarh      March         6569                7000
# 11     Chandigarh        May         6620                6000
# 12          Surat      April         9831               10000
# 13          Surat   February         9069                9000
# 14          Surat    January         8358                9000
# 15          Surat       June         8544               10000
# 16          Surat      March         9267                9000
# 17          Surat        May         9774               10000
# 18       Vadodara      April         5941                6500
# 19       Vadodara   February         5228                6000
# 20       Vadodara    January         4775                6000
# 21       Vadodara       June         4685                6500
# 22       Vadodara      March         5598                6000
# 23       Vadodara        May         5799                6500
# 24         Mysore      April         2603                2500
# 25         Mysore   February         2668                2000
# 26         Mysore    January         2485                2000
# 27         Mysore       June         2842                2500
# 28         Mysore      March         2633                2000
# 29         Mysore        May         3007                2500
# 30          Kochi      April         9762                9000
# 31          Kochi   February         7688                7500
# 32          Kochi    January         7344                7500
# 33          Kochi       June         6399                9000
# 34          Kochi      March         9495                7500
# 35          Kochi        May        10014                9000
# 36         Indore      April         7415                7500
# 37         Indore   February         7210                7000
# 38         Indore    January         6737                7000
# 39         Indore       June         6288                7500
# 40         Indore      March         7019                7000
# 41         Indore        May         7787                7500
# 42         Jaipur      April        11406                9500
# 43         Jaipur   February        15872               13000
# 44         Jaipur    January        14976               13000
# 45         Jaipur       June         9842                9500
# 46         Jaipur      March        13317               13000
# 47         Jaipur        May        11475                9500
# 48     Coimbatore      April         3661                3500
# 49     Coimbatore   February         3404                3500
# 50     Coimbatore    January         3651                3500
# 51     Coimbatore       June         3158                3500
# 52     Coimbatore      March         3680                3500
# 53     Coimbatore        May         3550                3500
# 54        Lucknow      April        10212               11000
# 55        Lucknow   February        12060               13000
# 56        Lucknow    January        10858               13000
# 57        Lucknow       June        10240               11000
# 58        Lucknow      March        11224               13000
# 59        Lucknow        May         9705               11000
#
#                 Trips_Target  Total_New_Passengers  target_new_passengers  \
# 0      Lags Target by -1.24%                  1845                   2000
# 1    Exceeds Target by 6.51%                  2380                   2500
# 2      Lags Target by -0.71%                  2513                   2500
# 3     Lags Target by -10.44%                  1900                   2000
# 4    Exceeds Target by 8.38%                  2170                   2500
# 5      Lags Target by -3.76%                  1939                   2000
# 6      Lags Target by -7.23%                  2496                   3000
# 7    Exceeds Target by 5.53%                  4104                   4000
# 8      Lags Target by -2.71%                  3920                   4000
# 9    Exceeds Target by 0.48%                  2430                   3000
# 10     Lags Target by -6.16%                  3228                   4000
# 11  Exceeds Target by 10.33%                  2730                   3000
# 12     Lags Target by -1.69%                  1843                   1500
# 13   Exceeds Target by 0.77%                  2254                   2000
# 14     Lags Target by -7.13%                  2432                   2000
# 15    Lags Target by -14.56%                  1540                   1500
# 16   Exceeds Target by 2.97%                  1946                   2000
# 17     Lags Target by -2.26%                  1611                   1500
# 18      Lags Target by -8.6%                  1637                   1500
# 19    Lags Target by -12.87%                  2146                   1800
# 20    Lags Target by -20.42%                  2089                   1800
# 21    Lags Target by -27.92%                  1104                   1500
# 22      Lags Target by -6.7%                  1763                   1800
# 23    Lags Target by -10.78%                  1388                   1500
# 24   Exceeds Target by 4.12%                  1836                   2000
# 25   Exceeds Target by 33.4%                  2107                   2000
# 26  Exceeds Target by 24.25%                  1957                   2000
# 27  Exceeds Target by 13.68%                  1874                   2000
# 28  Exceeds Target by 31.65%                  1986                   2000
# 29  Exceeds Target by 20.28%                  1921                   2000
# 30   Exceeds Target by 8.47%                  4939                   4000
# 31   Exceeds Target by 2.51%                  4367                   5000
# 32     Lags Target by -2.08%                  4865                   5000
# 33     Lags Target by -28.9%                  3011                   4000
# 34   Exceeds Target by 26.6%                  4865                   5000
# 35  Exceeds Target by 11.27%                  4369                   4000
# 36     Lags Target by -1.13%                  2351                   2000
# 37    Exceeds Target by 3.0%                  2878                   2700
# 38     Lags Target by -3.76%                  2843                   2700
# 39    Lags Target by -16.16%                  2021                   2000
# 40   Exceeds Target by 0.27%                  2742                   2700
# 41   Exceeds Target by 3.83%                  2028                   2000
# 42  Exceeds Target by 20.06%                  6120                   6000
# 43  Exceeds Target by 22.09%                 10789                  12000
# 44   Exceeds Target by 15.2%                 10423                  12000
# 45    Exceeds Target by 3.6%                  5775                   6000
# 46   Exceeds Target by 2.44%                  7417                  12000
# 47  Exceeds Target by 20.79%                  5332                   6000
# 48    Exceeds Target by 4.6%                  1242                   1000
# 49     Lags Target by -2.74%                  1647                   1500
# 50   Exceeds Target by 4.31%                  1822                   1500
# 51     Lags Target by -9.77%                  1226                   1000
# 52   Exceeds Target by 5.14%                  1538                   1500
# 53   Exceeds Target by 1.43%                  1039                   1000
# 54     Lags Target by -7.16%                  2311                   2000
# 55     Lags Target by -7.23%                  3529                   3200
# 56    Lags Target by -16.48%                  3465                   3200
# 57     Lags Target by -6.91%                  1971                   2000
# 58    Lags Target by -13.66%                  3159                   3200
# 59    Lags Target by -11.77%                  1825                   2000
#
#         New_Passenger_Target  Avg_Passenger_Rating  \
# 0      Lags Target by -7.75%              8.370595
# 1       Lags Target by -4.8%              8.465262
# 2    Exceeds Target by 0.52%              8.553939
# 3       Lags Target by -5.0%              8.402188
# 4      Lags Target by -13.2%              8.426287
# 5      Lags Target by -3.05%              8.387781
# 6      Lags Target by -16.8%              7.944484
# 7     Exceeds Target by 2.6%              8.027210
# 8       Lags Target by -2.0%              8.068135
# 9      Lags Target by -19.0%              7.893681
# 10     Lags Target by -19.3%              7.995129
# 11      Lags Target by -9.0%              7.910121
# 12  Exceeds Target by 22.87%              6.368528
# 13   Exceeds Target by 12.7%              6.494762
# 14   Exceeds Target by 21.6%              6.577531
# 15   Exceeds Target by 2.67%              6.356507
# 16      Lags Target by -2.7%              6.397648
# 17    Exceeds Target by 7.4%              6.328013
# 18   Exceeds Target by 9.13%              6.547383
# 19  Exceeds Target by 19.22%              6.803749
# 20  Exceeds Target by 16.06%              6.850471
# 21     Lags Target by -26.4%              6.438207
# 22     Lags Target by -2.06%              6.595391
# 23     Lags Target by -7.47%              6.461286
# 24      Lags Target by -8.2%              8.678448
# 25   Exceeds Target by 5.35%              8.794978
# 26     Lags Target by -2.15%              8.788732
# 27      Lags Target by -6.3%              8.621745
# 28      Lags Target by -0.7%              8.737182
# 29     Lags Target by -3.95%              8.608247
# 30  Exceeds Target by 23.48%              8.493137
# 31    Lags Target by -12.66%              8.560744
# 32      Lags Target by -2.7%              8.673066
# 33    Lags Target by -24.72%              8.477106
# 34      Lags Target by -2.7%              8.498368
# 35   Exceeds Target by 9.22%              8.431296
# 36  Exceeds Target by 17.55%              7.787458
# 37   Exceeds Target by 6.59%              7.894175
# 38    Exceeds Target by 5.3%              7.915393
# 39   Exceeds Target by 1.05%              7.778149
# 40   Exceeds Target by 1.56%              7.857530
# 41    Exceeds Target by 1.4%              7.744446
# 42    Exceeds Target by 2.0%              8.520603
# 43    Lags Target by -10.09%              8.666898
# 44    Lags Target by -13.14%              8.684963
# 45     Lags Target by -3.75%              8.578541
# 46    Lags Target by -38.19%              8.533228
# 47    Lags Target by -11.13%              8.463181
# 48   Exceeds Target by 24.2%              7.843485
# 49    Exceeds Target by 9.8%              7.952409
# 50  Exceeds Target by 21.47%              7.983292
# 51   Exceeds Target by 22.6%              7.852122
# 52   Exceeds Target by 2.53%              7.907065
# 53    Exceeds Target by 3.9%              7.756901
# 54  Exceeds Target by 15.55%              6.454465
# 55  Exceeds Target by 10.28%              6.573881
# 56   Exceeds Target by 8.28%              6.620740
# 57     Lags Target by -1.45%              6.349219
# 58     Lags Target by -1.28%              6.544102
# 59     Lags Target by -8.75%              6.358887
#
#     target_avg_passenger_rating        Avg_Rating_Target
# 0                          8.50    Lags Target by -1.52%
# 1                          8.50    Lags Target by -0.41%
# 2                          8.50  Exceeds Target by 0.63%
# 3                          8.50    Lags Target by -1.15%
# 4                          8.50    Lags Target by -0.87%
# 5                          8.50    Lags Target by -1.32%
# 6                          8.00    Lags Target by -0.69%
# 7                          8.00  Exceeds Target by 0.34%
# 8                          8.00  Exceeds Target by 0.85%
# 9                          8.00    Lags Target by -1.33%
# 10                         8.00    Lags Target by -0.06%
# 11                         8.00    Lags Target by -1.12%
# 12                         7.00    Lags Target by -9.02%
# 13                         7.00    Lags Target by -7.22%
# 14                         7.00    Lags Target by -6.04%
# 15                         7.00    Lags Target by -9.19%
# 16                         7.00    Lags Target by -8.61%
# 17                         7.00     Lags Target by -9.6%
# 18                         7.50    Lags Target by -12.7%
# 19                         7.50    Lags Target by -9.28%
# 20                         7.50    Lags Target by -8.66%
# 21                         7.50   Lags Target by -14.16%
# 22                         7.50   Lags Target by -12.06%
# 23                         7.50   Lags Target by -13.85%
# 24                         8.50   Exceeds Target by 2.1%
# 25                         8.50  Exceeds Target by 3.47%
# 26                         8.50   Exceeds Target by 3.4%
# 27                         8.50  Exceeds Target by 1.43%
# 28                         8.50  Exceeds Target by 2.79%
# 29                         8.50  Exceeds Target by 1.27%
# 30                         8.50    Lags Target by -0.08%
# 31                         8.50  Exceeds Target by 0.71%
# 32                         8.50  Exceeds Target by 2.04%
# 33                         8.50    Lags Target by -0.27%
# 34                         8.50    Lags Target by -0.02%
# 35                         8.50    Lags Target by -0.81%
# 36                         8.00    Lags Target by -2.66%
# 37                         8.00    Lags Target by -1.32%
# 38                         8.00    Lags Target by -1.06%
# 39                         8.00    Lags Target by -2.77%
# 40                         8.00    Lags Target by -1.78%
# 41                         8.00    Lags Target by -3.19%
# 42                         8.25  Exceeds Target by 3.28%
# 43                         8.25  Exceeds Target by 5.05%
# 44                         8.25  Exceeds Target by 5.27%
# 45                         8.25  Exceeds Target by 3.98%
# 46                         8.25  Exceeds Target by 3.43%
# 47                         8.25  Exceeds Target by 2.58%
# 48                         8.25    Lags Target by -4.93%
# 49                         8.25    Lags Target by -3.61%
# 50                         8.25    Lags Target by -3.23%
# 51                         8.25    Lags Target by -4.82%
# 52                         8.25    Lags Target by -4.16%
# 53                         8.25    Lags Target by -5.98%
# 54                         7.25   Lags Target by -10.97%
# 55                         7.25    Lags Target by -9.33%
# 56                         7.25    Lags Target by -8.68%
# 57                         7.25   Lags Target by -12.42%
# 58                         7.25    Lags Target by -9.74%
# 59                         7.25   Lags Target by -12.29%

# %% [markdown]
# ### 8. Highest and Lowest Repeat Passenger Rate (RPR%) by City and Month
# ### Analyse the Repeat Passenger Rate (RPR%) for each city across the six- month period. Identify the top 2 and bottom 2 cities based on their RPR% to determine which locations have the strongest and weakest rates.

# %%
df8 = fact_passenger_summary.groupby(['city_id']).agg(
    Total_Repeat_Passenger = ('repeat_passengers', 'sum'),
    Total_Passenger = ('total_passengers', 'sum')
).reset_index()
df8
# Out:
#   city_id  Total_Repeat_Passenger  Total_Passenger
# 0    AP01                    5108            17855
# 1    CH01                    5070            23978
# 2    GJ01                    8638            20264
# 3    GJ02                    4346            14473
# 4    KA01                    1477            13158
# 5    KL01                    7626            34042
# 6    MP01                    7216            22079
# 7    RJ01                    9682            55538
# 8    TN01                    2551            11065
# 9    UP01                    9597            25857

# %%
df8['RPR'] = round(df8['Total_Repeat_Passenger'] * 100 / df8['Total_Passenger'],2)
df8 = pd.merge(df8, dim_city, on=['city_id'], how='inner')
df8 = df8[['city_name', 'Total_Repeat_Passenger', 'Total_Passenger', 'RPR']].sort_values(by=['RPR'], ascending=[False])
print('Top 2 City in terms of RPR')
print(df8.head(2))
print('-'* 50)
print('Bottom 2 City in terms of RPR')
print(df8.tail(2))
# Out:
# Top 2 City in terms of RPR
#   city_name  Total_Repeat_Passenger  Total_Passenger    RPR
# 2     Surat                    8638            20264  42.63
# 9   Lucknow                    9597            25857  37.12
# --------------------------------------------------
# Bottom 2 City in terms of RPR
#   city_name  Total_Repeat_Passenger  Total_Passenger    RPR
# 7    Jaipur                    9682            55538  17.43
# 4    Mysore                    1477            13158  11.23

# %% [markdown]
# ### Similarly, analyse the RPR% by month across all cities and identify the months with the highest and lowest repeat passenger rates. This will help to pinpoint any seasonal patterns or months with higher repeat passenger loyalty.

# %%
fact_passenger_summary.head()
# Out:
#        month city_id  new_passengers  repeat_passengers  total_passengers
# 0 2024-01-01    AP01            2513                650              3163
# 1 2024-01-01    CH01            3920                720              4640
# 2 2024-01-01    GJ01            2432               1184              3616
# 3 2024-01-01    GJ02            2089                544              2633
# 4 2024-01-01    KA01            1957                172              2129

# %%
df8_1 = fact_passenger_summary.copy()
df8_1['month_name'] = df8_1['month'].dt.month_name()
df8_1['month_no'] = df8_1['month'].dt.month
df8_1
# Out:
#         month city_id  new_passengers  repeat_passengers  total_passengers  \
# 0  2024-01-01    AP01            2513                650              3163
# 1  2024-01-01    CH01            3920                720              4640
# 2  2024-01-01    GJ01            2432               1184              3616
# 3  2024-01-01    GJ02            2089                544              2633
# 4  2024-01-01    KA01            1957                172              2129
# 5  2024-01-01    KL01            4865                795              5660
# 6  2024-01-01    MP01            2843               1033              3876
# 7  2024-01-01    RJ01           10423               1422             11845
# 8  2024-01-01    TN01            1822                392              2214
# 9  2024-01-01    UP01            3465               1431              4896
# 10 2024-02-01    AP01            2380                790              3170
# 11 2024-02-01    CH01            4104                853              4957
# 12 2024-02-01    GJ01            2254               1313              3567
# 13 2024-02-01    GJ02            2146                610              2756
# 14 2024-02-01    KA01            2107                183              2290
# 15 2024-02-01    KL01            4367               1005              5372
# 16 2024-02-01    MP01            2878               1103              3981
# 17 2024-02-01    RJ01           10789               1661             12450
# 18 2024-02-01    TN01            1647                346              1993
# 19 2024-02-01    UP01            3529               1659              5188
# 20 2024-03-01    AP01            2170                923              3093
# 21 2024-03-01    CH01            3228                872              4100
# 22 2024-03-01    GJ01            1946               1494              3440
# 23 2024-03-01    GJ02            1763                759              2522
# 24 2024-03-01    KA01            1986                208              2194
# 25 2024-03-01    KL01            4865               1348              6213
# 26 2024-03-01    MP01            2742               1091              3833
# 27 2024-03-01    RJ01            7417               1840              9257
# 28 2024-03-01    TN01            1538                427              1965
# 29 2024-03-01    UP01            3159               1622              4781
# 30 2024-04-01    AP01            1845                992              2837
# 31 2024-04-01    CH01            2496                789              3285
# 32 2024-04-01    GJ01            1843               1551              3394
# 33 2024-04-01    GJ02            1637                862              2499
# 34 2024-04-01    KA01            1836                236              2072
# 35 2024-04-01    KL01            4939               1576              6515
# 36 2024-04-01    MP01            2351               1295              3646
# 37 2024-04-01    RJ01            6120               1736              7856
# 38 2024-04-01    TN01            1242                480              1722
# 39 2024-04-01    UP01            2311               1496              3807
# 40 2024-05-01    AP01            1939                951              2890
# 41 2024-05-01    CH01            2730                969              3699
# 42 2024-05-01    GJ01            1611               1606              3217
# 43 2024-05-01    GJ02            1388                868              2256
# 44 2024-05-01    KA01            1921                349              2270
# 45 2024-05-01    KL01            4369               1853              6222
# 46 2024-05-01    MP01            2028               1563              3591
# 47 2024-05-01    RJ01            5332               1842              7174
# 48 2024-05-01    TN01            1039                504              1543
# 49 2024-05-01    UP01            1825               1662              3487
# 50 2024-06-01    AP01            1900                802              2702
# 51 2024-06-01    CH01            2430                867              3297
# 52 2024-06-01    GJ01            1540               1490              3030
# 53 2024-06-01    GJ02            1104                703              1807
# 54 2024-06-01    KA01            1874                329              2203
# 55 2024-06-01    KL01            3011               1049              4060
# 56 2024-06-01    MP01            2021               1131              3152
# 57 2024-06-01    RJ01            5775               1181              6956
# 58 2024-06-01    TN01            1226                402              1628
# 59 2024-06-01    UP01            1971               1727              3698
#
#    month_name  month_no
# 0     January         1
# 1     January         1
# 2     January         1
# 3     January         1
# 4     January         1
# 5     January         1
# 6     January         1
# 7     January         1
# 8     January         1
# 9     January         1
# 10   February         2
# 11   February         2
# 12   February         2
# 13   February         2
# 14   February         2
# 15   February         2
# 16   February         2
# 17   February         2
# 18   February         2
# 19   February         2
# 20      March         3
# 21      March         3
# 22      March         3
# 23      March         3
# 24      March         3
# 25      March         3
# 26      March         3
# 27      March         3
# 28      March         3
# 29      March         3
# 30      April         4
# 31      April         4
# 32      April         4
# 33      April         4
# 34      April         4
# 35      April         4
# 36      April         4
# 37      April         4
# 38      April         4
# 39      April         4
# 40        May         5
# 41        May         5
# 42        May         5
# 43        May         5
# 44        May         5
# 45        May         5
# 46        May         5
# 47        May         5
# 48        May         5
# 49        May         5
# 50       June         6
# 51       June         6
# 52       June         6
# 53       June         6
# 54       June         6
# 55       June         6
# 56       June         6
# 57       June         6
# 58       June         6
# 59       June         6

# %%
df8_1 = df8_1.groupby(['city_id', 'month_name', 'month_no']).agg(
    Total_Repeat_Passenger = ('repeat_passengers', 'sum'),
    Total_Passenger = ('total_passengers', 'sum')
).reset_index()
df8_1.head()
# Out:
#   city_id month_name  month_no  Total_Repeat_Passenger  Total_Passenger
# 0    AP01      April         4                     992             2837
# 1    AP01   February         2                     790             3170
# 2    AP01    January         1                     650             3163
# 3    AP01       June         6                     802             2702
# 4    AP01      March         3                     923             3093

# %%
df8_1['RPR_Month_Wise'] = round(df8_1['Total_Repeat_Passenger'] * 100 / df8_1['Total_Passenger'],2)
df8_1 = pd.merge(df8_1, dim_city, on=['city_id'], how='inner')
df8_1 = df8_1[['city_name', 'month_name', 'Total_Repeat_Passenger', 'Total_Passenger', 'RPR_Month_Wise', 'month_no']]
df8_1.sort_values(by=['city_name', 'month_no'], ascending=[True, True], inplace=True)
df8_1[['city_name', 'month_name', 'Total_Repeat_Passenger', 'Total_Passenger', 'RPR_Month_Wise']]
# Out:
#         city_name month_name  Total_Repeat_Passenger  Total_Passenger  \
# 8      Chandigarh    January                     720             4640
# 7      Chandigarh   February                     853             4957
# 10     Chandigarh      March                     872             4100
# 6      Chandigarh      April                     789             3285
# 11     Chandigarh        May                     969             3699
# 9      Chandigarh       June                     867             3297
# 50     Coimbatore    January                     392             2214
# 49     Coimbatore   February                     346             1993
# 52     Coimbatore      March                     427             1965
# 48     Coimbatore      April                     480             1722
# 53     Coimbatore        May                     504             1543
# 51     Coimbatore       June                     402             1628
# 38         Indore    January                    1033             3876
# 37         Indore   February                    1103             3981
# 40         Indore      March                    1091             3833
# 36         Indore      April                    1295             3646
# 41         Indore        May                    1563             3591
# 39         Indore       June                    1131             3152
# 44         Jaipur    January                    1422            11845
# 43         Jaipur   February                    1661            12450
# 46         Jaipur      March                    1840             9257
# 42         Jaipur      April                    1736             7856
# 47         Jaipur        May                    1842             7174
# 45         Jaipur       June                    1181             6956
# 32          Kochi    January                     795             5660
# 31          Kochi   February                    1005             5372
# 34          Kochi      March                    1348             6213
# 30          Kochi      April                    1576             6515
# 35          Kochi        May                    1853             6222
# 33          Kochi       June                    1049             4060
# 56        Lucknow    January                    1431             4896
# 55        Lucknow   February                    1659             5188
# 58        Lucknow      March                    1622             4781
# 54        Lucknow      April                    1496             3807
# 59        Lucknow        May                    1662             3487
# 57        Lucknow       June                    1727             3698
# 26         Mysore    January                     172             2129
# 25         Mysore   February                     183             2290
# 28         Mysore      March                     208             2194
# 24         Mysore      April                     236             2072
# 29         Mysore        May                     349             2270
# 27         Mysore       June                     329             2203
# 14          Surat    January                    1184             3616
# 13          Surat   February                    1313             3567
# 16          Surat      March                    1494             3440
# 12          Surat      April                    1551             3394
# 17          Surat        May                    1606             3217
# 15          Surat       June                    1490             3030
# 20       Vadodara    January                     544             2633
# 19       Vadodara   February                     610             2756
# 22       Vadodara      March                     759             2522
# 18       Vadodara      April                     862             2499
# 23       Vadodara        May                     868             2256
# 21       Vadodara       June                     703             1807
# 2   Visakhapatnam    January                     650             3163
# 1   Visakhapatnam   February                     790             3170
# 4   Visakhapatnam      March                     923             3093
# 0   Visakhapatnam      April                     992             2837
# 5   Visakhapatnam        May                     951             2890
# 3   Visakhapatnam       June                     802             2702
#
#     RPR_Month_Wise
# 8            15.52
# 7            17.21
# 10           21.27
# 6            24.02
# 11           26.20
# 9            26.30
# 50           17.71
# 49           17.36
# 52           21.73
# 48           27.87
# 53           32.66
# 51           24.69
# 38           26.65
# 37           27.71
# 40           28.46
# 36           35.52
# 41           43.53
# 39           35.88
# 44           12.01
# 43           13.34
# 46           19.88
# 42           22.10
# 47           25.68
# 45           16.98
# 32           14.05
# 31           18.71
# 34           21.70
# 30           24.19
# 35           29.78
# 33           25.84
# 56           29.23
# 55           31.98
# 58           33.93
# 54           39.30
# 59           47.66
# 57           46.70
# 26            8.08
# 25            7.99
# 28            9.48
# 24           11.39
# 29           15.37
# 27           14.93
# 14           32.74
# 13           36.81
# 16           43.43
# 12           45.70
# 17           49.92
# 15           49.17
# 20           20.66
# 19           22.13
# 22           30.10
# 18           34.49
# 23           38.48
# 21           38.90
# 2            20.55
# 1            24.92
# 4            29.84
# 0            34.97
# 5            32.91
# 3            29.68

# %%
df8_1['rnk1'] = df8_1.groupby(['city_name'])['RPR_Month_Wise'].rank(method='dense', ascending=False)
df8_1['rnk2'] = df8_1.groupby(['city_name'])['RPR_Month_Wise'].rank(method='dense', ascending=True)
df8_2 = df8_1[(df8_1['rnk1']==1) | (df8_1['rnk2']==1)]
df8_2[['city_name', 'month_name', 'Total_Repeat_Passenger', 'Total_Passenger', 'RPR_Month_Wise']]
# Out:
#         city_name month_name  Total_Repeat_Passenger  Total_Passenger  \
# 8      Chandigarh    January                     720             4640
# 9      Chandigarh       June                     867             3297
# 49     Coimbatore   February                     346             1993
# 53     Coimbatore        May                     504             1543
# 38         Indore    January                    1033             3876
# 41         Indore        May                    1563             3591
# 44         Jaipur    January                    1422            11845
# 47         Jaipur        May                    1842             7174
# 32          Kochi    January                     795             5660
# 35          Kochi        May                    1853             6222
# 56        Lucknow    January                    1431             4896
# 59        Lucknow        May                    1662             3487
# 25         Mysore   February                     183             2290
# 29         Mysore        May                     349             2270
# 14          Surat    January                    1184             3616
# 17          Surat        May                    1606             3217
# 20       Vadodara    January                     544             2633
# 21       Vadodara       June                     703             1807
# 2   Visakhapatnam    January                     650             3163
# 0   Visakhapatnam      April                     992             2837
#
#     RPR_Month_Wise
# 8            15.52
# 9            26.30
# 49           17.36
# 53           32.66
# 38           26.65
# 41           43.53
# 44           12.01
# 47           25.68
# 32           14.05
# 35           29.78
# 56           29.23
# 59           47.66
# 25            7.99
# 29           15.37
# 14           32.74
# 17           49.92
# 20           20.66
# 21           38.90
# 2            20.55
# 0            34.97
